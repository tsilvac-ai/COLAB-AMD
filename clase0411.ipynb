# %% [markdown]
# <a href="https://colab.research.google.com/github/tsilvac-ai/COLAB-AMD/blob/main/clase0411.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
TopPlayers = pd.read_csv("https://www.dropbox.com/s/v5h8uzswjvco2wc/Tennis_World_Number_1s.csv?dl=1")
TopPlayers
# Out:
#           Tennis_Player  Total_Weeks_at_No_1  \
# 0         Roger Federer                  310
# 1          Pete Sampras                  286
# 2            Ivan Lendl                  270
# 3         Jimmy Connors                  268
# 4        Novak Djokovic                  264
# 5          Rafael Nadal                  196
# 6          John McEnroe                  170
# 7            Bjorn Borg                  109
# 8          Andre Agassi                  101
# 9        Lleyton Hewitt                   80
# 10        Stefan Edberg                   72
# 11          Jim Courier                   58
# 12      Gustavo Kuerten                   43
# 13          Andy Murray                   41
# 14         Ilie Nastase                   40
# 15        Mats Wilander                   20
# 16         Andy Roddick                   13
# 17         Boris Becker                   12
# 18          Marat Safin                    9
# 19  Juan Carlos Ferrero                    8
# ...

# %%
TopPlayers.describe()                                #Estadisticas descriptivas de el dataframe
# Out:
#        Total_Weeks_at_No_1  Maximum_Consectutive_Weeks_at_no_1  \
# count            26.000000                           26.000000
# mean             92.269231                           50.269231
# std             106.108080                           59.769931
# min               1.000000                            1.000000
# 25%               8.250000                            8.000000
# 50%              42.000000                           28.500000
# 75%             154.750000                           57.500000
# max             310.000000                          237.000000
#
#        Years_End_no_1      Titles   Prize_Money  Unnamed: 7
# count       26.000000   26.000000  2.600000e+01         0.0
# mean         1.769231   47.884615  3.000085e+07         NaN
# std          1.965863   28.588567  3.703442e+07         NaN
# min          0.000000   11.000000  1.062408e+06         NaN
# 25%          0.000000   23.750000  1.141659e+07         NaN
# ...

# %%
#verificar valores nulos por columnas
TopPlayers.isna()
# Out:
#     Tennis_Player  Total_Weeks_at_No_1  Maximum_Consectutive_Weeks_at_no_1  \
# 0           False                False                               False
# 1           False                False                               False
# 2           False                False                               False
# 3           False                False                               False
# 4           False                False                               False
# 5           False                False                               False
# 6           False                False                               False
# 7           False                False                               False
# 8           False                False                               False
# 9           False                False                               False
# 10          False                False                               False
# ...

# %%
TopPlayers.isna().sum()
# Out:
# Tennis_Player                          0
# Total_Weeks_at_No_1                    0
# Maximum_Consectutive_Weeks_at_no_1     0
# Years_End_no_1                         0
# Careers_Wins_Losses                    0
# Titles                                 0
# Prize_Money                            0
# Unnamed: 7                            26
# dtype: int64

# %%
TopPlayers.drop("Unnamed: 7", axis=1, inplace=True)

# %%
TopPlayers.head(5)
# Out:
#     Tennis_Player  Total_Weeks_at_No_1  Maximum_Consectutive_Weeks_at_no_1  \
# 0   Roger Federer                  310                                 237
# 1    Pete Sampras                  286                                 102
# 2      Ivan Lendl                  270                                 157
# 3   Jimmy Connors                  268                                 160
# 4  Novak Djokovic                  264                                 122
#
#    Years_End_no_1 Careers_Wins_Losses  Titles  Prize_Money
# 0               5            1222-265     102    126266005
# 1               6             762-222      64     43280489
# 2               4            1068-242      94     21262417
# 3               5            1274-282     109      8641040
# 4               5             871-182      75    134684000

# %%
TopPlayers.columns
# Out:
# Index(['Tennis_Player', 'Total_Weeks_at_No_1',
#        'Maximum_Consectutive_Weeks_at_no_1', 'Years_End_no_1',
#        'Careers_Wins_Losses', 'Titles', 'Prize_Money'],
#       dtype='object')

# %%
TopPlayers.dtypes
# Out:
# Tennis_Player                         object
# Total_Weeks_at_No_1                    int64
# Maximum_Consectutive_Weeks_at_no_1     int64
# Years_End_no_1                         int64
# Careers_Wins_Losses                   object
# Titles                                 int64
# Prize_Money                            int64
# dtype: object

# %%
TopPlayers.shape #Cantidad de filas y columnas del datafame
# Out:
# (26, 7)

# %%
TopPlayers
# Out:
#           Tennis_Player  Total_Weeks_at_No_1  \
# 0         Roger Federer                  310
# 1          Pete Sampras                  286
# 2            Ivan Lendl                  270
# 3         Jimmy Connors                  268
# 4        Novak Djokovic                  264
# 5          Rafael Nadal                  196
# 6          John McEnroe                  170
# 7            Bjorn Borg                  109
# 8          Andre Agassi                  101
# 9        Lleyton Hewitt                   80
# 10        Stefan Edberg                   72
# 11          Jim Courier                   58
# 12      Gustavo Kuerten                   43
# 13          Andy Murray                   41
# 14         Ilie Nastase                   40
# 15        Mats Wilander                   20
# 16         Andy Roddick                   13
# 17         Boris Becker                   12
# 18          Marat Safin                    9
# 19  Juan Carlos Ferrero                    8
# ...
